# %%
import random
movies=["STARWARS","TOYSTORY","AVENGERS","FROZEN","HER","GRAVITY","SKYFALL","INCEPTION","LION","PINK","JOKER","ANNABELLE","FROZEN","QUEEN","NOTEBOOK","IT"]

def createq(movie):
    lettr=list(movie)
    temp=[]
    for i in range (0,len(movie)):
        if(lettr[i]==" "):
            temp.append(" ")
        else: 
            temp.append("*")
    qn="".join(str(x) for x in temp)     
    return qn        


def ispresent(movie,letter):
    a=movie.count(letter)
    if(a==0):
        return False
    else:
        return True
    
    
def fill(qn,movie,letter):
    li=list(movie)
    qn_li=list(qn)
    temp=[]
    for i in range (len(movie)):
        if (li[i]==' ' or li[i]==letter):
            temp.append(li[i])
        else:
            if qn_li[i]=="*" :
                temp.append("*")
            else:
                temp.append(li[i])
    b="".join(str(x) for x in temp)     
    return b 
                                          
    
def play():
    p1=input("enter the name: ")
    p2=input("enter the name: ")
    pp1=0
    pp2=0
    turn=0
    willing= True
    while (willing):
        if(turn%2==0):
            print("Its the turn of ",p1)
            m=random.choice(movies)
            q=createq(m)
            modified=q
            print(q)
            not_guessed= True
            while (not_guessed):
                l=input("Enter the letter in uppercase: ")
                if(ispresent(m,l)):
                    #fillletters
                    modified=fill(modified,m,l)
                    print(modified)
                    d=input("Press 1 to guess the name and 2 to continue: ")
                    if (d=='1'):
                        ans=input("enter your answer: ")
                        if (ans==m):
                            print("correct")
                            pp1=pp1+1
                            not_guessed= False
                            print(p1,"Your score is: ",ppt)
                        else:
                            print("Wrong answer, try again.")
                    else:
                        print("Enter any one of shown!")
                else:
                    print(l," not found!")
            c=input("press 1 to continue and 0 to quit")
            if (c=='0'):
                print("Your score is:",p1)
                print("Your score is:",p2)
                print("Thankyou for playing")
                willing=False
        else:
            print("Its the turn of ",p1)
            m=random.choice(movies)
            q=createq(m)
            print(q)
            modified=q
            #print(q)
            not_guessed= True
            while(not_guessed):
                l=input("Enter the letter in uppercase: ")
                if (ispresent(m,l)):
                    #fillletters
                    modified=fill(modified,m,l)
                    print(modified)
                    d=input("Press 1 to guess the name and 2 to continue: ")
                    if (d=='1'):
                        ans=input("enter your answer")
                        if ans==m:
                            print("correct")
                            pp2=pp2+1
                            not_guessed= False
                            print(p2,"Your score is: ",pp2)
                        else:
                            print("Wrong answer, try again.")
                    else:
                        print("Enter any of the shown!")
                else:
                    print(l,"Letter not found!")
            c=input("press 1 to continue and 0 to quit")
            if (c=='0'):
                print("Your score is:",p1)
                print("Your score is:",p2)
                print("Thankyou for playing")
                willing=False  
        turn=turn+1             
play()
# Out:
# enter the name: DE
# enter the name: DF
# Its the turn of  DE
# *********
